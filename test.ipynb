# %%
# library imports
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
from spacy.tokens import DocBin
import json
from datetime import datetime
from tqdm import tqdm
import re
from pathlib import Path

# %%
version = "23"
train_spacy_file_name = "input/Hindistan_"+ version + "_train.spacy"
dev_spacy_file_name = "input/Hindistan_"+ version + "_dev.spacy"
keys_file_name = "data/keys_fasil_"+ version + ".csv"
product_file_name = "data/Hindistan-"+ version + "-test verisi-ham.xlsx"
product_out_file_name = "data/products_"+ version + ".csv"
product_sheet_name = "Sayfa1"
train_data_out_file_name = "data/training_data_"+ version + ".txt"
test_data_out_file_name = "data/test_data_"+ version + ".txt"
product_column_name = "PRODUCT_DESCRIPTION"
result_file_name = "data/result_"+ version + ".xlsx"

# %%
keys = pd.read_csv(keys_file_name)
product_df = pd.read_excel(product_file_name, sheet_name=product_sheet_name)
product_df['product'] = product_df[product_column_name].str.lower()
#product_df= product_df[['product']]
#product_df = pd.DataFrame(product_df['product'].unique(), columns=['product'])
#product_df.to_csv(product_out_file_name, index=False)
product_df.head()
# Out:
#             ID                        PRODUCT_DESCRIPTION  \
# 0  sm23-t23-01  PET FOODS (BUFFALO OFFALS UNFIT FOR HUMA
# 1  sm23-t23-02                     SINGADE ATTA 500GMX29
# 2  sm23-t23-03  DISPOSABLE HOUSE FLY TRAP (LUT NO:AD3206
# 3  sm23-t23-04  FINISHED FISH MEAL (PULVERISED SIEVED)PO
# 4  sm23-t23-05                                 FISH MEAL
#
#                                      product
# 0  pet foods (buffalo offals unfit for huma
# 1                     singade atta 500gmx29
# 2  disposable house fly trap (lut no:ad3206
# 3  finished fish meal (pulverised sieved)po
# 4                                 fish meal

# %%
# load the trained model
nlp_output = spacy.load("output/model-last")
result_df = pd.DataFrame(columns=["ID", "desc", "product"])

columns = list(result_df)
data = []
for i in range(len(product_df)) :
    text = product_df.iloc[i, 2]
    id = product_df.iloc[i, 0]
    #print("-------------------------------")
    doc = nlp_output(text)
    # customize the label colors
    colors = {"PRODUCT": "linear-gradient(90deg, #E1D436, #F59710)"}
    options = {"ents": ["PRODUCT"], "colors": colors}

    
    displacy.render(doc, style="ent", options=options)
 
    
    # print out the identified entities
    for ent in doc.ents:
        if ent.label_ == "PRODUCT":
            #print(ent.text, ent.label_)
            #print(text, "------>", ent.text)
            values = [id, text, ent.text]
            zipped = zip(columns, values)
            a_dictionary = dict(zipped)
            data.append(a_dictionary)
result_df = result_df.append(data, True)
result_df.to_excel(result_file_name, index=False)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">pet foods (
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     buffalo offals unfit for huma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# C:\ProgramData\Anaconda3\envs\stance\lib\site-packages\spacy\displacy\__init__.py:200: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">singade atta 500gmx29 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">disposable house fly trap (lut no:ad3206 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">finished
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (pulverised sieved)po </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  - animal feed grade ( batch c </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (un fit for human consumption) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (unfinished) (unfit for human consumption) (sip no.13328/2021/dadf dtd 02.09.2021) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (unfit for human consumption)p </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  1960 bags x 50 kgs(we indent t </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  4000 hdpe bagsx50 kgs(we inten </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in powder form </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in powder form (unfit for huma </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in powder form, we intend to c </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in powder from(unfit for human </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in powdered form </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , we intend to claim rewards un </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fishmeal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (unfit for human consumption)pa </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">house fly bait 25 gram sachet (lut ad320 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">house fly baited trap (lut ad32062100192 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">in powder form
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">in powder form indian fishmeal (unfit fo </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">in powder form indian steam dried fish m </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">in powder form indian steam dried red f </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">in powder form indian steam dried red fi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">indian
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  pkg: 50kg pp bags </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">indian steam dried
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">indian steam dried
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  50kg x4000 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">indian steam dried
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  packed in 4 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">indian steam dried fishmeal in powdered </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">powder
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (unfit for human consu </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">powder
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (unfit for human consum </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">powder
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  meal(unfit for human consump </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">processed
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (dried, pulverised s </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">red fishmeal (pangasius hypophthalmus) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">reusable house fly trap (lut no:ad320621 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">steam dried
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (for feed purpose) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">steam dried
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  50kgx2000 hdpe bag </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tuna fishmeal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in 40kg bags </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">2,3-dihydro-1,2 -pyrrolo (2.3-b)pyridine </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">43010000 qrill tm antarctic
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     krill meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  eq msc-c-52985 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">43010300 qrill tm antarctic
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     krill meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  msc-c-52985 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">43010500 qrill tm antarctic
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     krill meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (lf) eq 25kg msc-c-52985 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chicken feed - grower (50kg bags) packed </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chicken feed - layer (50kg bags) packed </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">fish feed (
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for nursery feed) ( </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish soluble powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  100 bags x 20 kgs(we </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish soluble powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  1000 foil bag x 20 k </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish soluble powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  20 kgs x 100 bags(we </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish soluble powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  20kg x 480 bags(we i </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish soluble powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ,rodtep </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fishmeal semi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  finished(unfit for human consumption)import permit no.12872 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fishmeal semi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  finished(unfit for human consumption)import permit no.14826/2022/dadf dated 31.01.2022</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fishmeal semi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  finished(unfit for human consumption)import permit no.14826/2022/dadf dt.31/01/2022 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">peruvian steam dried
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (202.160 mts) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">qrill antarctic
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     krill meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  25kg msc-c-52 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">atoot lock arian 40mm </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">atoot lock arian 50mm </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dried
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish anchovy sd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (feed material ) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dried fish
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     assorted dired fish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (feed mat </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dried fish
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     assorted dried fish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (feed mat </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dried fish sd shrimps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  1 - 2 cm (feed ma </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dried fish sd shrimps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  1- 2 cm (feed mate </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dried fish sd shrimps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  1-2 cm (feed mater </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dried fish sd shrimps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  2 - 4 cm (feed ma </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dried fish sd shrimps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  2- 4 cm (feed mate </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dried fish sd shrimps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  3-5 cm (feed mater </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">fish maile </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (poultry feed) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ingredients (api) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ingredients (as per invoice) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fish meal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ingredients(api) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">fishmeal ingredients (as per invoice) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">kapoor lock arian 3&quot; </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">multtipurpose lock </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">raw material for fish feed (grade c) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">2]ti2122/3232 dt.30.12.2021 amt 13860.88 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">3]ti2122/3295 dt.4.1.2022 amt rs.20316.6 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">4]ti2122/3231 dt.30.12.2021 amt 19413.75 </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corn gluten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  feed hipro packing: in pp ba </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corn gluten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  feed hipro pp bag
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corn glute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">corn/
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maize gluten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  feed(detail as per inv </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">feeds </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">lut number arn) : ad270321066070l date </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">maize enriched
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (indian
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corn gluten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">supplier : gulshan polyols ltd gst 24aab </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">supplier tax inv 1]ti2122/3232 dt.30.12. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  flaker </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  jadhi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  jhadi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  palish </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  powder </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cattle feed
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rice bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chieua bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chiru bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chiru bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua falaker </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua k a bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua k bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua k bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua ka bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua ka bhus. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua ka bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua ka
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua kabhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chirua kla bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chiura
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chiura bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chrua bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chuda ka bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chura bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chura bhusi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">chura ka bhus </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corn fibre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (n) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">corn/
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maize gluten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  feed(detail as per inv </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">d to e
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wheat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  500 gm </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">daan banawal chirua </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dana banawal chirua </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dana banawal chura </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dana bannawal chirua </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dana bannawal chura </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dana bannwal chirua </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dana bnawal chirua </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dana bnawal chirua ka tukda </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">de oiled
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rice bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">falaker </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">flaker </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">flaker
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">flooker </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">fulaker </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maize corn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maize corn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (as per invoice) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">oat fiber, canadian harvest 300-58 (
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bleached oat plant fiber
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ) (raw material for nutraceutical use) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">oil cake </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">oil cake bag </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">paddy husk </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">palish </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">powder
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">rejket chura </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">religious pooja item - tharbai </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rice bran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# ...
# </mark>
#  b2 80-sd(feed additive)do not contain animal originsubstance -germany </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rovimix
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  b6 feed grade (poultry feed supplement/not for medicinal-human use) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">salinomycin 12 % granular ( feed premix / additive not for human use / not for medicinal use / for p</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">salinomycin 12% granular feed grade (animal feed additive/
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feed supplement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ) (item does not contain a</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">sanacore gm </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">sanixap </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">selenium trituration 1% (2.4% sodium sel </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">selisseo (r) 0.1% se (
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal feed grade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# -not fit for human consumption-not for medicinal use-for anim</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">selisseo 0.1% se 25kg bag (animal feed additives) (not formedicinal use) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">selisseo 0.1% se(selenium premix feed grade)(animal feed additives) (not for human/medicinal use). </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     selko
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# -ph (feed additive for use in poultry feed not for medical use) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">sid-o-min syrup 200ml batch no: b093, mf </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">smart heart budgies(enhanced vitamins - minerals) id8bbg2911kg x 12bags/ctn </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">smartheart rabbit food - junior id8rb531 smartheart brand 1kgx12bags/carton </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">smartheart rabbit food raspberry flavor id8rb571 smartheartbrand 1kgx12bags/carton </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">soft coat </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">soham healthcare inc.(2020-22)gstn:24adn </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soya husk pellets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ( animal feed ) packed </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">star coat 500ml </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">teklad global 14% protein rodent maintenance diet (t.2014.15)(450 bags) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">tiamulin hydrogen fumarate 10% granular (feed premix/additives not for human/medicinal use for poult</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">tiamulin hydrogen fumarate 10% granulated premix feed grade(animal
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feed supplement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# /feed additive) (i</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">t-molder powder 25 kg </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">tox c+25 kg </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">toxbind (
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal feed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  supplements) (not for medicinal/human use,used for poultry feed only) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">toxfin 300 dry 25kg,mfg:feb22exp:aug24,l </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">toxfin 360 dry (preparation of a kind us </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">toxfin dry (preparation of a kind used i </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">toxfin dry 25kg (mfg:nov 21,exp:nov 23) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">toxikill - 25 kg bag (promotional materi </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">toxo-mx (feed additives) (not for medicinal use) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">toxo-xl (feed additives for use in poultry feed not for medicinal use) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ts acid protease 300,000 u/gm (specification:powder) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">turmoshield </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">tylosin phosphate 10 pct granular feed grade (
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal feed supplement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  / feed additive )(item does not</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">tylosin phosphate 10 percent granular-
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     poultry feed supplement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">tylosin phosphate 10% granular feed premix not for humanuse not for medicinal use and for animal pou</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">tylovet 10% (tylosin phosphate 10% ) feed premix / additives( do not contain animal origin substance</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">udrstrong - h 1 lit </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">vetmulin 10% (tiamulin hydrogen fumarate )feed premix/additives (doesnotcontain animal origin) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">vitamin ad3 (1000/200) iu/g (feed grade) (use foranimal/poultry feed only not for medicinal &amp; human </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">vitamin b12 1% feed grade(feed additive)do not contain animal origin substance- france </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">vitamin b12 1% feed grade(feed additive)do not contain animal origin substance -france </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">vitamin b2 80% (not for human / medicinal use, use for feedgrade only) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">vitamin b2 80% feed grade (animal poultry feed additives use) (animal/poultry feed only / not for hu</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">vitamin d3 feed grade 0.5miu/gm (animal feed additive/ feedsupplement) (item does not contain any su</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">wormout gel 100 ml export-
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal feed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  supplements </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">wormout gel 1l-
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal feed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  suppliments </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">wormout gel 250ml export-
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal feed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  suppliments </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">xs adimix precision batch 2212204-02(animal feed additives/premixes/supplements) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">yeast culture (halor tid) (poultry feed supplement, not forhuman use, for
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal feed supplement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  onl</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">yeast hydrolysate 55% (fish feed formulation) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">yellow exotic feed 20 kg (104 bags)(pet food for hobby animals) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">yiduozyme x-4001 powder,cellul ase 100,000 u/g(
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  feedsupplement) </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">zagromix bd-851-vitamin premix for poultry feed-not for medicinal use </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">zagromix br-835-not for medicinal use and to be used for manufacture of poultry feed only </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">zagromix br-839-feed supplement for poultry feed </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">zagromix lr-859-not for medicinal use and to be used for manufacture of poultry feed only </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">zagromix lr-859-vitamin feed supplement for poultry feed-notfor medicinal use </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">zagromix lr-891-
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vitamin feed supplement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for poultry feed notfor medicinal use </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">zagromix lr-891-vitamin premix for poultry feed-not for medicinal use </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">zenifix micotoxin binder (feed grade) (
# <mark class="entity" style="background: linear-gradient(90deg, #E1D436, #F59710); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     animal feed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  supplement/ feed additive) (item does not contain</div></span>
